# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('babies(Preprocessed).csv')

# %%
dataset
# Out:
#        age   gestation  parity  height  weight  smoke  bwt
# 0     27.0  284.000000       0    62.0   100.0    0.0  120
# 1     33.0  282.000000       0    64.0   135.0    0.0  113
# 2     28.0  279.000000       0    64.0   115.0    1.0  128
# 3     36.0  279.338512       0    69.0   190.0    0.0  123
# 4     23.0  282.000000       0    67.0   125.0    1.0  108
# ...    ...         ...     ...     ...     ...    ...  ...
# 1231  27.0  275.000000       1    60.0   100.0    0.0  113
# 1232  24.0  265.000000       0    67.0   120.0    0.0  128
# 1233  30.0  291.000000       0    65.0   150.0    1.0  130
# 1234  21.0  281.000000       1    65.0   110.0    0.0  125
# 1235  38.0  297.000000       0    65.0   129.0    0.0  117
#
# [1236 rows x 7 columns]

# %%
X = dataset.drop('bwt', axis=1)
y = dataset['bwt']

# %% [markdown]
# # Heatmap

# %%
correlation_matrix = dataset.corr()
plt.figure(figsize=(9, 7))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# # Histograms

# %%
import matplotlib.pyplot as plt

# List of features
features = ['age', 'gestation', 'parity', 'height', 'weight', 'smoke', 'bwt']

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(10, 5))

# Flatten the 2D array of subplots
axes = axes.flatten()

# Plot histograms for each feature
for i, feature in enumerate(features):
    axes[i].hist(dataset[feature], bins=20, edgecolor='black')
    axes[i].set_title(f'Histogram of {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Frequency')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # Density Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of features
features = ['age', 'gestation', 'parity', 'height', 'weight', 'smoke', 'bwt']

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(10, 5))

# Flatten the 2D array of subplots
axes = axes.flatten()

# Plot density plots for each feature
for i, feature in enumerate(features):
    sns.kdeplot(data=dataset, x=feature, ax=axes[i], fill=True)
    axes[i].set_title(f'Density Plot of {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Density')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # Box Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of features
features = ['age', 'gestation', 'parity', 'height', 'weight', 'smoke', 'bwt']

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(10, 5))

# Flatten the 2D array of subplots
axes = axes.flatten()

# Plot transparent box plots for each feature
for i, feature in enumerate(features):
    sns.boxplot(x=feature, data=dataset, ax=axes[i], boxprops=dict(alpha=0.5))
    axes[i].set_title(f'Box Plot of {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Value')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # Violin Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of features
features = ['age', 'gestation', 'parity', 'height', 'weight', 'smoke', 'bwt']

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(16, 8))

# Flatten the 2D array of subplots
axes = axes.flatten()

# Plot violin plots for each feature
for i, feature in enumerate(features):
    sns.violinplot(x=feature, data=dataset, ax=axes[i], inner="quartile")
    axes[i].set_title(f'Violin Plot of {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Value')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of features
features = ['age', 'gestation', 'parity', 'height', 'weight', 'bwt']

# Create pair plots for scatter plots with a specified height
sns.pairplot(dataset[features], height=1)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
